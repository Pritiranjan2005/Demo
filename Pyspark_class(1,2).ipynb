# %% [markdown]
# <a href="https://colab.research.google.com/github/Pritiranjan2005/Demo/blob/main/Pyspark_class(1%2C2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyspark

# %%
import pandas as pd
pd.read_excel('/content/text2.xlsx')
# Out:
#        Name   Age
# 0      Krish   31
# 1  Sudhanshu   30
# 2      Sunny   29

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Practise').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://1a671634ce3a:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.4</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practise</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark=spark.read.csv('/content/text3.csv')

# %%
df_pyspark
# Out:
# DataFrame[_c0: string, _c1: string]

# %%
df_pyspark.show()
# Out:
# +---------+---+
# |      _c0|_c1|
# +---------+---+
# |    Name |Age|
# |    Krish| 31|
# |Sudhanshu| 30|
# |    Sunny| 29|
# +---------+---+

# %%
df_pyspark=spark.read.option('header','true').csv('/content/text3.csv')

# %%
type(df_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name : string (nullable = true)
#  |-- Age: string (nullable = true)

# %%
from pandas._libs.lib import infer_dtype
##read the dataset
df1_pyspark=spark.read.option('header','true').csv('/content/class2.csv',inferSchema=True)

# %%
##check the schema
## bydefault it store all the datatype as a string after inferSchema=true it gave all the data type gave as different
df1_pyspark.printSchema()
# Out:
# root
#  |-- Name : string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)

# %%
df1_pyspark=spark.read.option('header','true').csv('/content/class2.csv',inferSchema=True)
df1_pyspark.show()
# Out:
# +---------+---+----------+
# |    Name |Age|Experience|
# +---------+---+----------+
# |    Krish| 31|        10|
# |Sudhanshu| 30|         8|
# |    Sunny| 29|         4|
# +---------+---+----------+

# %%
type(df1_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df1_pyspark.columns
# Out:
# ['Name ', 'Age', 'Experience']

# %%
df1_pyspark.head(2)
# Out:
# [Row(Name ='Krish', Age=31, Experience=10),
#  Row(Name ='Sudhanshu', Age=30, Experience=8)]

# %%
df1_pyspark.show()
# Out:
# +---------+---+----------+
# |    Name |Age|Experience|
# +---------+---+----------+
# |    Krish| 31|        10|
# |Sudhanshu| 30|         8|
# |    Sunny| 29|         4|
# +---------+---+----------+

# %%
df1_pyspark.select('Name')
# Out:
# {"ts": "2026-09-08 05:32:36.180", "level": "ERROR", "logger": "DataFrameQueryContextLogger", "msg": "[UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `Name` cannot be resolved. Did you mean one of the following? [`Name `, `Age`, `Experience`, `Experience After 2 years`]. SQLSTATE: 42703", "context": {"file": "java.base/jdk.internal.reflect.NativeMethodAccessorImpl.invoke0(Native Method)", "line": "", "fragment": "col", "errorClass": "UNRESOLVED_COLUMN.WITH_SUGGESTION"}, "exception": {"class": "Py4JJavaError", "msg": "An error occurred while calling o425.select.\n: org.apache.spark.sql.AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `Name` cannot be resolved. Did you mean one of the following? [`Name `, `Age`, `Experience`, `Experience After 2 years`]. SQLSTATE: 42703;\n'Project ['Name]\n+- Project [Name #299, Age#300, Experience#301, (Experience#301 + 2) AS Experience After 2 years#319]\
# ...

# %%
##adding and droping column
df1_pyspark=df1_pyspark.withColumn('Experience After 2 years',df1_pyspark['Experience']+2)

# %%
df1_pyspark.show()
# Out:
# +---------+---+----------+------------------------+
# |    Name |Age|Experience|Experience After 2 years|
# +---------+---+----------+------------------------+
# |    Krish| 31|        10|                      12|
# |Sudhanshu| 30|         8|                      10|
# |    Sunny| 29|         4|                       6|
# +---------+---+----------+------------------------+

# %%
##drop the column
df1_pyspark=df1_pyspark.drop('Experience After 2 years')

# %%
df1_pyspark.show()
# Out:
# +---------+---+----------+
# |    Name |Age|Experience|
# +---------+---+----------+
# |    Krish| 31|        10|
# |Sudhanshu| 30|         8|
# |    Sunny| 29|         4|
# +---------+---+----------+

# %%
##rename the column
df1_pyspark=df1_pyspark.withColumnRenamed('  Name','Emp Name')
df1_pyspark.show()
# Out:
# +---------+---+----------+
# |    Name |Age|Experience|
# +---------+---+----------+
# |    Krish| 31|        10|
# |Sudhanshu| 30|         8|
# |    Sunny| 29|         4|
# +---------+---+----------+

# %%
df1_pyspark.show()
# Out:
# +---------+---+----------+
# |    Name |Age|Experience|
# +---------+---+----------+
# |    Krish| 31|        10|
# |Sudhanshu| 30|         8|
# |    Sunny| 29|         4|
# +---------+---+----------+
