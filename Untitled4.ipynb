# %% [markdown]
# <a href="https://colab.research.google.com/github/Pritiranjan2005/Demo/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyspark
import pandas as pd

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName('Missing').getOrCreate()

# %%
training=spark.read.csv('/content/Book6.csv',header=True,inferSchema=True)

# %%
training.show()
# Out:
# +---------+------------+------+
# |     Name| Departments|Salary|
# +---------+------------+------+
# |    Krish|Data Science| 10000|
# |    Krish|         IOT|  5000|
# |   Mahesh|    Big Data|  4000|
# |Sudhanshu|         IOT|  4000|
# |Sudhanshu|Data Science|  3000|
# |Sudhanshu|    Big Data|200000|
# |    Sunny|Data Science| 10000|
# |   Mahesh|Data Science|  5000|
# +---------+------------+------+

# %%
training.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Departments: string (nullable = true)
#  |-- Salary: integer (nullable = true)

# %%
training.columns
# Out:
# ['Name', 'Departments', 'Salary']

# %%
training1=spark.read.csv('/content/filter.csv',header=True,inferSchema=True)

# %%
training1.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |   Subham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
# [age,experience]-->new feature--->independent feature
from pyspark.ml.feature import VectorAssembler
featureassembler=VectorAssembler(inputCols=['age','Experience'],outputCol="Independent Feature")

# %%
output=featureassembler.transform(training1)

# %%
output.show()
# Out:
# +---------+---+----------+------+-------------------+
# |     Name|age|Experience|Salary|Independent Feature|
# +---------+---+----------+------+-------------------+
# |    Krish| 31|        10| 30000|        [31.0,10.0]|
# |Sudhanshu| 30|         8| 25000|         [30.0,8.0]|
# |    Sunny| 29|         4| 20000|         [29.0,4.0]|
# |     Paul| 24|         3| 20000|         [24.0,3.0]|
# |   Harsha| 21|         1| 15000|         [21.0,1.0]|
# |   Subham| 23|         2| 18000|         [23.0,2.0]|
# +---------+---+----------+------+-------------------+

# %%
output.columns
# Out:
# ['Name', 'age', 'Experience', 'Salary', 'Independent Feature']

# %%
finalized_data=output.select("Independent Feature","Salary")
finalized_data.show()
# Out:
# +-------------------+------+
# |Independent Feature|Salary|
# +-------------------+------+
# |        [31.0,10.0]| 30000|
# |         [30.0,8.0]| 25000|
# |         [29.0,4.0]| 20000|
# |         [24.0,3.0]| 20000|
# |         [21.0,1.0]| 15000|
# |         [23.0,2.0]| 18000|
# +-------------------+------+

# %%
  from pyspark.ml.regression import LinearRegression
  ## train test split
  train_data,test_data=finalized_data.randomSplit([0.75,0.25])
  regressor=LinearRegression(featuresCol='Independent Feature',labelCol='Salary')
  regressor=regressor.fit(train_data)

# %%
###coefficent
regressor.coefficients
# Out:
# DenseVector([-115.8558, 1602.7301])

# %%
##intercepts
regressor.intercept
# Out:
# 16904.795239761996

# %%
##prediction
pred_result=regressor.evaluate(test_data)
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# /tmp/ipykernel_2493/628128683.py in <cell line: 0>()
#       1 ##prediction
# ----> 2 pred_result=regressor.evaluate(test_data)
#
# /usr/local/lib/python3.13/dist-packages/pyspark/ml/regression.py in evaluate(self, dataset)
#     508         if not isinstance(dataset, DataFrame):
#     509             raise TypeError("dataset must be a DataFrame but got %s." % type(dataset))
# --> 510         java_lr_summary = self._call_java("evaluate", dataset)
#     511         return LinearRegressionSummary(java_lr_summary)
#     512
#
# /usr/local/lib/python3.13/dist-packages/pyspark/ml/util.py in wrapped(self, name, *args)
#     252                 return deserialize(properties)
#     253         else:
# --> 254             return f(self, name, *args)
#     255
#     256     return cast(FuncT, wrapped)
#
# ...
